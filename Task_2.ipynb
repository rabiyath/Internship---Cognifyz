# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load dataframe
df = pd.read_csv('Dataset .csv')
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
#create a refined dataframe
mydf = df[['Restaurant ID','Restaurant Name','Cuisines','Price range','Aggregate rating','Votes']]
mydf
# Out:
#       Restaurant ID           Restaurant Name  \
# 0           6317637          Le Petit Souffle
# 1           6304287          Izakaya Kikufuji
# 2           6300002    Heat - Edsa Shangri-La
# 3           6318506                      Ooma
# 4           6314302               Sambo Kojin
# ...             ...                       ...
# 9546        5915730               Naml۱ Gurme
# 9547        5908749              Ceviz A��ac۱
# 9548        5915807                     Huqqa
# 9549        5916112               A���k Kahve
# 9550        5927402  Walter's Coffee Roastery
#
#                               Cuisines  Price range  Aggregate rating  Votes
# 0           French, Japanese, Desserts            3               4.8    314
# 1                             Japanese            3               4.5    591
# 2     Seafood, Asian, Filipino, Indian            4               4.4    270
# 3                      Japanese, Sushi            4               4.9    365
# ...

# %%
#handle missing values
mydf.isna().sum()
# Out:
# Restaurant ID       0
# Restaurant Name     0
# Cuisines            9
# Price range         0
# Aggregate rating    0
# Votes               0
# dtype: int64

# %%
mydf = dfR.dropna()
mydf.isna().sum()
# Out:
# Restaurant ID       0
# Restaurant Name     0
# Cuisines            0
# Price range         0
# Aggregate rating    0
# Votes               0
# dtype: int64

# %%
mydf.duplicated().sum()
# Out:
# 0

# %%
mydf['Restaurant Name'].duplicated().sum()
# Out:
# 2105

# %%
mydf['Restaurant Name'].value_counts()
# Out:
# Restaurant Name
# Cafe Coffee Day             83
# Domino's Pizza              79
# Subway                      63
# Green Chick Chop            51
# McDonald's                  48
#                             ..
# The Town House Cafe          1
# The G.T. Road                1
# The Darzi Bar & Kitchen      1
# Smoke On Water               1
# Walter's Coffee Roastery     1
# Name: count, Length: 7437, dtype: int64

# %%
#sorting the restaurants by name and rating
mydf = mydf.sort_values(by=['Restaurant Name','Aggregate rating'],ascending=False)
mydf.head()
# Out:
#       Restaurant ID       Restaurant Name  \
# 9523        6000871     �ukura��a Sofras۱
# 3120       18222559  {Niche} - Cafe & Bar
# 9334        7100938              wagamama
# 9454        6401789                tashas
# 4659       18361747    t Lounge by Dilmah
#
#                                          Cuisines  Price range  \
# 9523                                Kebab, Izgara            3
# 3120  North Indian, Chinese, Italian, Continental            3
# 9334                              Japanese, Asian            4
# 9454                          Cafe, Mediterranean            4
# 4659                          Cafe, Tea, Desserts            2
#
#       Aggregate rating  Votes
# 9523               4.4    296
# 3120               4.1    492
# 9334               3.7    131
# 9454               4.1    374
# 4659               3.6     34

# %%
mydf[mydf["Restaurant Name"]=="Cafe Coffee Day"].head()
# Out:
#       Restaurant ID  Restaurant Name Cuisines  Price range  Aggregate rating  \
# 6430           5595  Cafe Coffee Day     Cafe            1               3.6
# 8432            594  Cafe Coffee Day     Cafe            1               3.6
# 3946         305736  Cafe Coffee Day     Cafe            1               3.5
# 5877           8828  Cafe Coffee Day     Cafe            1               3.5
# 3001            596  Cafe Coffee Day     Cafe            1               3.4
#
#       Votes
# 6430     58
# 8432    125
# 3946     35
# 5877     50
# 3001    277

# %%
#removing duplicate entries of same restaurant name
mydf = mydf.drop_duplicates('Restaurant Name',keep='first')
mydf
# Out:
#       Restaurant ID       Restaurant Name  \
# 9523        6000871     �ukura��a Sofras۱
# 3120       18222559  {Niche} - Cafe & Bar
# 9334        7100938              wagamama
# 9454        6401789                tashas
# 4659       18361747    t Lounge by Dilmah
# ...             ...                   ...
# 8692       18317511          #Urban Caf��
# 6998       18336489           #OFF Campus
# 2613       18311951          #InstaFreeze
# 9148       18378803          #Dilliwaala6
# 2459        3100446                   #45
#
#                                          Cuisines  Price range  \
# 9523                                Kebab, Izgara            3
# 3120  North Indian, Chinese, Italian, Continental            3
# 9334                              Japanese, Asian            4
# 9454                          Cafe, Mediterranean            4
# 4659                          Cafe, Tea, Desserts            2
# ...                                           ...          ...
# ...

# %%
mydf['Restaurant Name'].value_counts()
# Out:
# Restaurant Name
# �ukura��a Sofras۱           1
# French Toast                1
# Fourteen Eleven Tea Cafe    1
# Fozzie's Pizzaiolo          1
# Frasers                     1
#                            ..
# Pizza Street                1
# Pizza Treat                 1
# Pizza Yum                   1
# Pizza �� Bessa              1
# #45                         1
# Name: count, Length: 7437, dtype: int64

# %%
mydf = mydf[mydf['Aggregate rating']>3.9]
mydf
# Out:
#       Restaurant ID          Restaurant Name  \
# 9523        6000871        �ukura��a Sofras۱
# 3120       18222559     {Niche} - Cafe & Bar
# 9454        6401789                   tashas
# 9385        6113857           sketch Gallery
# 1837       18418247               feel ALIVE
# ...             ...                      ...
# 1468       18408054      19 Flavours Biryani
# 2484       18233317           145 Kala Ghoda
# 2292        2100784  11th Avenue Cafe Bistro
# 751         2600031        10 Downing Street
# 351        17057397                   'Ohana
#
#                                          Cuisines  Price range  \
# 9523                                Kebab, Izgara            3
# 3120  North Indian, Chinese, Italian, Continental            3
# 9454                          Cafe, Mediterranean            4
# 9385                        British, Contemporary            4
# 1837       North Indian, American, Asian, Biryani            3
# ...

# %%
#splitting cuisines into list
mydf['Cuisines'] = mydf['Cuisines'].str.split(', ')
mydf
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_5676\320566305.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mydf['Cuisines'] = mydf['Cuisines'].str.split(', ')
#       Restaurant ID          Restaurant Name  \
# 9523        6000871        �ukura��a Sofras۱
# 3120       18222559     {Niche} - Cafe & Bar
# 9454        6401789                   tashas
# 9385        6113857           sketch Gallery
# 1837       18418247               feel ALIVE
# ...             ...                      ...
# 1468       18408054      19 Flavours Biryani
# 2484       18233317           145 Kala Ghoda
# 2292        2100784  11th Avenue Cafe Bistro
# 751         2600031        10 Downing Street
# 351        17057397                   'Ohana
#
# ...

# %%
mydf = mydf.explode('Cuisines')
mydf
# Out:
#       Restaurant ID          Restaurant Name      Cuisines  Price range  \
# 9523        6000871        �ukura��a Sofras۱         Kebab            3
# 9523        6000871        �ukura��a Sofras۱        Izgara            3
# 3120       18222559     {Niche} - Cafe & Bar  North Indian            3
# 3120       18222559     {Niche} - Cafe & Bar       Chinese            3
# 3120       18222559     {Niche} - Cafe & Bar       Italian            3
# ...             ...                      ...           ...          ...
# 2292        2100784  11th Avenue Cafe Bistro       Italian            2
# 2292        2100784  11th Avenue Cafe Bistro   Continental            2
# 751         2600031        10 Downing Street  North Indian            3
# 751         2600031        10 Downing Street       Chinese            3
# 351        17057397                   'Ohana      Hawaiian            3
#
#       Aggregate rating  Votes
# 9523               4.4    296
# 9523               4.4    296
# ...

# %%
mydf['Cuisines'].value_counts()
# Out:
# Cuisines
# North Indian    270
# Italian         237
# Chinese         200
# Continental     199
# Cafe            177
#                ...
# Pub Food          1
# Durban            1
# Irish             1
# Persian           1
# Sunda             1
# Name: count, Length: 128, dtype: int64

# %%
restoXcuisines = pd.crosstab(mydf['Restaurant Name'], mydf['Cuisines'])

# %%
restoXcuisines
# Out:
# Cuisines                 Afghani  African  American  Andhra  Arabian  \
# Restaurant Name
# 'Ohana                         0        0         0       0        0
# 10 Downing Street              0        0         0       0        0
# 11th Avenue Cafe Bistro        0        0         1       0        0
# 145 Kala Ghoda                 0        0         0       0        0
# 19 Flavours Biryani            0        0         0       0        0
# ...                          ...      ...       ...     ...      ...
# feel ALIVE                     0        0         1       0        0
# sketch Gallery                 0        0         0       0        0
# tashas                         0        0         0       0        0
# {Niche} - Cafe & Bar           0        0         0       0        0
# �ukura��a Sofras۱              0        0         0       0        0
#
# Cuisines                 Argentine  Asian  Asian Fusion  Australian  Awadhi  \
# Restaurant Name
# ...

# %%
mydf['Restaurant Name'].sample(20, random_state=194)
# Out:
# 7729                           Indian Saffron Co.
# 3013                           Naturals Ice Cream
# 422         Sansei Seafood Restaurant & Sushi Bar
# 81                       Sainte Marie Gastronomia
# 3310                                Spezia Bistro
# 7849                              Cafeteria & Co.
# 2407                             India Restaurant
# 637                               Sheroes Hangout
# 1858                           Boombox Brewstreet
# 2393    Aangan - Downtown Multicuisine Restaurant
# 9339                                         Bank
# 7067                                     Pa Pa Ya
# 728                                          Toit
# 6447                                 Bakerz Lodge
# 9469                           The Belgian Triple
# 7727                                 Cafe Connect
# 9532                                    Masaba��۱
# 734                            ECHOES Koramangala
# 3703                   Sakley's The Mountain Cafe
# ...

# %%
from sklearn.metrics import jaccard_score

# %%
print(jaccard_score(restoXcuisines.loc["Olive Bistro"].values,
                    restoXcuisines.loc["Rose Cafe"].values))
# Out:
# 0.3333333333333333

# %%
from scipy.spatial.distance import pdist, squareform

# %%
jaccardDist = pdist(restoXcuisines.values, metric='jaccard')
jaccardMatrix = squareform(jaccardDist)
jaccardSim = 1 - jaccardMatrix
dfJaccard = pd.DataFrame(
    jaccardSim,
    index=restoXcuisines.index,
    columns=restoXcuisines.index)

dfJaccard
# Out:
# Restaurant Name          'Ohana  10 Downing Street  11th Avenue Cafe Bistro  \
# Restaurant Name
# 'Ohana                      1.0                0.0                 0.000000
# 10 Downing Street           0.0                1.0                 0.000000
# 11th Avenue Cafe Bistro     0.0                0.0                 1.000000
# 145 Kala Ghoda              0.0                0.0                 0.000000
# 19 Flavours Biryani         0.0                0.0                 0.000000
# ...                         ...                ...                      ...
# feel ALIVE                  0.0                0.2                 0.142857
# sketch Gallery              0.0                0.0                 0.000000
# tashas                      0.0                0.0                 0.200000
# {Niche} - Cafe & Bar        0.0                0.5                 0.333333
# �ukura��a Sofras۱           0.0                0.0                 0.000000
#
# ...

# %%
mydf['Restaurant Name'].sample(20)
# Out:
# 2293                                       Caf�� Riverrun
# 2348    Monarch Restaurant - Holiday Inn Jaipur City C...
# 1839                                            Prankster
# 9410                                               Mughli
# 616                                               Nando's
# 4526                                       Coffee & Cream
# 2441                                        Indian Summer
# 1478                                              Dudleys
# 2349    Chao Chinese Bistro - Holiday Inn Jaipur City ...
# 2407                                     India Restaurant
# 1871                                  Bottles and Barrels
# 445                        Goose Feathers Cafe and Bakery
# 3453                                           Ooh Lala !
# 2315                                            Churrolto
# 186                                Berry Patch Restaurant
# 59                                             Apraz�_vel
# ...
